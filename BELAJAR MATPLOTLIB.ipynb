# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0, 5, 10, 15, 20])
y = np.array([0, 10, 5, 30, 40])

plt.plot(x,y)

plt.title("PERKEMBANGAN USIA", loc="left")
plt.xlabel("average pulse")
plt.ylabel("cognitive")

plt.show()
